# %% [markdown]
# # Building Deep Neural Network with TensorFlow

# %% [markdown]
# # Introduction to Computer Vision with Deep Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Computer vision is the field of study that focuses on teaching computers to interpret, understand and analyze visual information from the world, just like humans do.
# - It enables machines to process and analyze images and videos, making it possible for computers to understand the content and context of visual data.

# %% [markdown]
# ![Screenshot 2023-05-12 132137.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Here's a 5-step explanation of computer vision:**
# - **Image Acquisition:** This is the process of capturing visual information, such as images and videos, and converting them into a format that can be processed by computers.
#
# - **Image Pre-processing:** This step involves cleaning and transforming raw images into a format that is suitable for analysis. This can include techniques such as cropping, resizing, normalizing and removing noise from images.
#
# - **Feature Extraction:** In this step, computers analyze images and extract relevant features, such as lines, edges, and shapes, which are used to make predictions and classifications.
#
# - **Machine Learning:** This step involves using algorithms, such as deep learning, to train computers to recognize patterns and make predictions based on the visual information they receive.
#
# - **Object Recognition and Image Understanding:** The final step involves using the information extracted in the previous steps to recognize objects, classify images, and make predictions about the content and context of visual data. This allows computers to understand and analyze images and videos in the same way that humans do.

# %% [markdown]
# ## Fashion MNIST Dataset

# %% [markdown]
# https://www.openml.org/search?type=data&status=active&id=40996
#
# https://github.com/zalandoresearch/fashion-mnist

# %% [markdown]
# - Fashion-MNIST is a dataset of Zalando's article images, consisting of a training set of 60,000 examples and a test set of 10,000 examples.
# - Each example is a 28x28 grayscale image, associated with a label from 10 classes.
# - Fashion-MNIST is intended to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install openml
# !python -m pip install --upgrade pip
# https://www.openml.org/
# https://openml.github.io/openml-python/main/examples/30_extended/datasets_tutorial.html

classes = ['tshirt', 'trouser', 'pullover', 'dress','coat',
            'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']
# Out:
# Requirement already satisfied: openml in c:\users\lenovo\anaconda3\lib\site-packages (0.15.1)
# Requirement already satisfied: liac-arff>=2.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (2.5.0)
# Requirement already satisfied: xmltodict in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (0.14.2)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from openml) (2.31.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (1.3.2)
# Requirement already satisfied: python-dateutil in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (2.8.2)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (1.5.3)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (1.10.1)
# Requirement already satisfied: numpy>=1.6.2 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from openml) (1.26.1)
# Requirement already satisfied: minio in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (7.2.15)
# Requirement already satisfied: pyarrow in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (11.0.0)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from openml) (4.65.0)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from openml) (23.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.0.0->openml) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from python-dateutil->openml) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn>=0.18->openml) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn>=0.18->openml) (3.1.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from minio->openml) (2023.11.17)
# Requirement already satisfied: urllib3 in c:\users\lenovo\anaconda3\lib\site-packages (from minio->openml) (1.25.3)
# Requirement already satisfied: argon2-cffi in c:\users\lenovo\anaconda3\lib\site-packages (from minio->openml) (21.3.0)
# Requirement already satisfied: pycryptodome in c:\users\lenovo\anaconda3\lib\site-packages (from minio->openml) (3.23.0)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\anaconda3\lib\site-packages (from minio->openml) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->openml) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from requests->openml) (3.4)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm->openml) (0.4.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\lenovo\anaconda3\lib\site-packages (from argon2-cffi->minio->openml) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.21)

# %%
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
fashion_mnist = fetch_openml(data_id=40996, cache=True)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:1022: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
print(fashion_mnist.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
X = fashion_mnist['data']
y = fashion_mnist['target']

print(fashion_mnist['DESCR'])
# Out:
# **Author**: Han Xiao, Kashif Rasul, Roland Vollgraf
# **Source**: [Zalando Research](https://github.com/zalandoresearch/fashion-mnist)
# **Please cite**: Han Xiao and Kashif Rasul and Roland Vollgraf, Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning Algorithms, arXiv, cs.LG/1708.07747
#
# Fashion-MNIST is a dataset of Zalando's article images, consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. Fashion-MNIST is intended to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.
#
# Raw data available at: https://github.com/zalandoresearch/fashion-mnist
#
# ### Target classes
# Each training and test example is assigned to one of the following labels:
# Label  Description
# 0  T-shirt/top
# 1  Trouser
# 2  Pullover
# 3  Dress
# 4  Coat
# 5  Sandal
# 6  Shirt
# 7  Sneaker
# 8  Bag
# 9  Ankle boot
#
# Downloaded from openml.org.

# %%
X.shape, y.shape
# Out:
# ((70000, 784), (70000,))

# %%
plt.rcParams['figure.figsize'] = (12,5)
plt.rcParams['figure.dpi'] = 100

class_indices = y.unique()
class_indices = list(class_indices)
class_indices.sort()

for i in class_indices:
  plt.subplot(2,5, int(i)+1)
  img = X[y == i].iloc[0].to_numpy().reshape(28,28)
  plt.imshow(img)
  plt.title(classes[int(i)])

plt.tight_layout()

# %%
y
# Out:
# 0        9
# 1        0
# 2        0
# 3        3
# 4        0
#         ..
# 69995    9
# 69996    1
# 69997    8
# 69998    1
# 69999    5
# Name: class, Length: 70000, dtype: category
# Categories (10, object): ['0', '1', '2', '3', ..., '6', '7', '8', '9']

# %%
# fashion_mnist['frame']

# %% [markdown]
# ### Designing a Deep Neural Network (DNN)

# %% [markdown]
# ![Screenshot 2023-05-12 132137.jpg](data:image/jpeg;base64,...)

# %%
y = y.astype('int')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X/255, y, test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((56000, 784), (14000, 784), (56000,), (14000,))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential

# %%
X_train.shape[1]
# Out:
# 784

# %%
def get_model():
  model = Sequential()
  model.add(Flatten(input_shape=(X_train.shape[1],)))
  model.add(Dense(128, activation='relu'))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(10, activation='softmax'))

  return model

# sigmoid -> for binary
# softmax -> for categorical

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 109386 (427.29 KB)
# Trainable params: 109386 (427.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
(784+1)*128 + (128+1)*64 + (64+1)*10
# Out:
# 109386

# %%
model.layers
# Out:
# [<keras.src.layers.reshaping.flatten.Flatten at 0x2115851cc50>,
#  <keras.src.layers.core.dense.Dense at 0x21164d96cd0>,
#  <keras.src.layers.core.dense.Dense at 0x21164de9710>,
#  <keras.src.layers.core.dense.Dense at 0x21164d87290>]

# %%
weights, biases = model.layers[3].get_weights()
len(biases)
# Out:
# 10

# %%
model = get_model()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1750/1750 [==============================] - 16s 8ms/step - loss: 0.4980 - accuracy: 0.8216 - val_loss: 0.3850 - val_accuracy: 0.8628
# Epoch 2/10
# 1750/1750 [==============================] - 12s 7ms/step - loss: 0.3705 - accuracy: 0.8643 - val_loss: 0.3872 - val_accuracy: 0.8578
# Epoch 3/10
# 1750/1750 [==============================] - 13s 7ms/step - loss: 0.3421 - accuracy: 0.8737 - val_loss: 0.3758 - val_accuracy: 0.8638
# Epoch 4/10
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.3169 - accuracy: 0.8827 - val_loss: 0.3396 - val_accuracy: 0.8748
# Epoch 5/10
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.2982 - accuracy: 0.8892 - val_loss: 0.3298 - val_accuracy: 0.8823
# Epoch 6/10
# 1750/1750 [==============================] - 12s 7ms/step - loss: 0.2832 - accuracy: 0.8934 - val_loss: 0.3238 - val_accuracy: 0.8820
# Epoch 7/10
# 1750/1750 [==============================] - 13s 7ms/step - loss: 0.2708 - accuracy: 0.8983 - val_loss: 0.3417 - val_accuracy: 0.8775
# Epoch 8/10
# 1750/1750 [==============================] - 13s 7ms/step - loss: 0.2641 - accuracy: 0.9009 - val_loss: 0.3383 - val_accuracy: 0.8778
# Epoch 9/10
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2501 - accuracy: 0.9056 - val_loss: 0.3203 - val_accuracy: 0.8919
# Epoch 10/10
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2414 - accuracy: 0.9091 - val_loss: 0.3202 - val_accuracy: 0.8884

# %%
history.history
# Out:
# {'loss': [0.4979660212993622,
#   0.37053707242012024,
#   0.3421030044555664,
#   0.31693923473358154,
#   0.29820528626441956,
#   0.2832062542438507,
#   0.27075380086898804,
#   0.26412925124168396,
#   0.25011470913887024,
#   0.24136899411678314],
#  'accuracy': [0.8216071724891663,
#   0.8643035888671875,
#   0.8737499713897705,
#   0.8826785683631897,
#   0.889214277267456,
#   0.8933571577072144,
#   0.8983392715454102,
#   0.9009285569190979,
#   0.9055714011192322,
#   0.9090892672538757],
#  'val_loss': [0.3849911689758301,
#   0.38723623752593994,
#   0.3758196234703064,
#   0.3395843207836151,
#   0.3297500014305115,
#   0.32379552721977234,
#   0.3417069911956787,
#   0.33825209736824036,
#   0.3203258216381073,
#   0.32020390033721924],
#  'val_accuracy': [0.8627856969833374,
#   0.857785701751709,
#   0.8637857437133789,
#   0.8747857213020325,
#   0.8822857141494751,
#   0.8820000290870667,
#   0.8774999976158142,
#   0.8777857422828674,
#   0.8918571472167969,
#   0.8883571624755859]}

# %% [markdown]
# ## Discovering Overfitting - Early Stopping
# - Early stopping is a technique that allows you to stop training a neural network when it stops improving on a validation dataset.
# - This is a form of regularization that can be used to prevent overfitting on a training dataset.
# - The easiest way to implement early stopping is to use the EarlyStopping callback provided by Keras.

# %% [markdown]
# ![Screenshot 2023-05-12 165230.jpg](data:image/jpeg;base64,...)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if (logs.get('accuracy')-logs.get('val_accuracy')) > 0.01:
      print("Validation Accuracy fell below 1% of training accuracy. Cancelling Training!!!")
      self.model.stop_training = True

callbacks = myCallback()

model = get_model()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), callbacks=[callbacks])
# Out:
# Epoch 1/10
# 1750/1750 [==============================] - 16s 8ms/step - loss: 0.5037 - accuracy: 0.8214 - val_loss: 0.4080 - val_accuracy: 0.8559
# Epoch 2/10
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.3780 - accuracy: 0.8621 - val_loss: 0.3707 - val_accuracy: 0.8655
# Epoch 3/10
# 1750/1750 [==============================] - 12s 7ms/step - loss: 0.3393 - accuracy: 0.8742 - val_loss: 0.3378 - val_accuracy: 0.8780
# Epoch 4/10
# 1750/1750 [==============================] - 12s 7ms/step - loss: 0.3151 - accuracy: 0.8837 - val_loss: 0.3239 - val_accuracy: 0.8828
# Epoch 5/10
# 1748/1750 [============================>.] - ETA: 0s - loss: 0.2988 - accuracy: 0.8879Validation Accuracy fell below 1% of training accuracy. Cancelling Training!!!
# 1750/1750 [==============================] - 13s 7ms/step - loss: 0.2987 - accuracy: 0.8879 - val_loss: 0.3469 - val_accuracy: 0.8747

# %% [markdown]
# ## Model Save and Load for Prediction

# %%
model_classes = {'model': model, 'classes': classes}

# %%
import pickle as pkl
pkl.dump(model_classes, open('model_fashion_mnist.pkl', 'wb'))

# %%
loaded_model = pkl.load(open('model_fashion_mnist.pkl', 'rb'))

# %%
loaded_model
# Out:
# {'model': <keras.src.engine.sequential.Sequential at 0x21165020990>,
#  'classes': ['tshirt',
#   'trouser',
#   'pullover',
#   'dress',
#   'coat',
#   'sandal',
#   'shirt',
#   'sneaker',
#   'bag',
#   'ankle boot']}

# %%
loaded_model['model'].predict(X_train)
# Out:
# 1750/1750 [==============================] - 8s 4ms/step
# array([[6.8759209e-01, 2.3646867e-03, 8.4084366e-04, ..., 2.2731577e-09,
#         7.3296014e-06, 2.5081283e-07],
#        [3.3815630e-02, 5.3077319e-04, 8.8958248e-02, ..., 5.8783095e-05,
#         4.7027644e-02, 5.3437292e-05],
#        [1.2883556e-01, 3.5033110e-04, 5.6641120e-01, ..., 2.5256406e-05,
#         6.8074297e-03, 5.8865655e-05],
#        ...,
#        [6.3967168e-02, 4.4735276e-05, 3.5732615e-01, ..., 6.7590555e-04,
#         4.8376895e-03, 2.6617889e-04],
#        [9.0968046e-05, 1.4167108e-06, 3.4254453e-01, ..., 2.9611808e-08,
#         1.1676814e-05, 1.2895485e-10],
#        [4.1652209e-01, 8.3471599e-07, 2.0963785e-01, ..., 1.8460847e-06,
#         2.5808301e-03, 4.1314703e-07]], dtype=float32)

# %%
pred = loaded_model['model'].predict(X_train.iloc[0].to_numpy().reshape(1,784))
# Out:
# 1/1 [==============================] - 0s 60ms/step

# %%
idx = np.argmax(pred[0])

# %%
loaded_model['classes'][idx]
# Out:
# 'tshirt'
